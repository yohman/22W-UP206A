# %% [markdown]
# # Mapping Past LWCF Grants Outdoor Recreation Legacy Partnership
#
# - https://lwcf.tplgis.org/mappast/
#
# The ORLP layer for their interactive map can be found here:
#
# - https://server5.tplgis.org/arcgis5/rest/services/National/LWCF_Data/FeatureServer/4
#
# Querying where program = 'ORLP' and exporting as a geojson file (included in this folder)

# %%
import geopandas as gpd
import contextily as ctx

# to give more power to your figures (plots)
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
orlp = gpd.read_file('orlp.geojson')

# %%
orlp.head()
# Out:
#    OBJECTID UNIQUE_ID PROGRAM PROG_SUB STATE         COUNTY          MUNIC  \
# 0     47787   SS35104    ORLP     None    TX         Travis         Austin
# 1     56925   SS45617    ORLP     None    CA    Los Angeles       El Monte
# 2     62956   SS45615    ORLP     None    AR      Sebastian     Fort Smith
# 3     66666   SS45625    ORLP     None    NC       Guilford     Greensboro
# 4     75450    SS2760    ORLP     None    CA  San Francisco  San Francisco
#
#       CD              SPONSAGEN                         TITLE  ... ACRESFEE  \
# 0  TX-35         City of Austin  Edward Rendon Sr. Metro Park  ...     None
# 1  CA-32       City of El Monte                   Zamora Park  ...     None
# 2   AR-3     City of Fort Smith     May Branch Railroad Trail  ...     None
# 3   NC-6     City of Greensboro         Peeler Community Park  ...     None
# 4  CA-12  City of San Francisco                 Bay View Park  ...     None
#
# ...

# %%
orlp = orlp.to_crs(epsg=3857)

# %%
fig,ax = plt.subplots(figsize=(12,12))

orlp.plot(ax=ax,markersize=100,alpha=0.5,linewidth=2,edgecolor='white',color='red')

# get rid of the axis
ax.axis('off');

# basemap from carto that has a dark background (easier to see)
ctx.add_basemap(ax)
