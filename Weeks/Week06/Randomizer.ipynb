# %% [markdown]
# # Randomizer
#
# Who goes first? Let's roll the python dice...

# %%
import pandas as pd

# %%
# Create a data list of students and topics
students = [['Erik Felix', 'Kevin Liu', 'The Arroyo Seco Collective'],
['Nicole Matteson', 'Chaithra Ananthakrishna Navada', 'TOD Housing'],
['Bailey Lai', 'Monica Gonzalez Jimenez', 'Equitable Access to Safe Biking Infrastructure in LA'],
['Elena Savignano', 'Yasmina Yusuf', 'Transportation in South Africa'],
['George Karam', 'Omer Sohail', 'Cycling in the City of LA: The Nexus of Urban Design and Traffic Safety'],
['Carolyn Chu', 'Leslie Velasquez', 'Where do we need more parks in Los Angeles?'],
['Ariana Hernandez','Sim Bun', 'Mapping green gentrification and park equity in the City of Los Angeles'],
['Estefany Garcia', 'Mica O\'Brien', 'Affordable Housing and Community Health'],
['Elliot Shaw', 'Michael Rosen', 'Seeing The Forest, Not The Trees: Tree Equity in Oakland, California'],
['Lupe Velez', 'Antonia Izuogu', 'Equity in Policy: Toxic Facilities in Oxnard and Malibu'],
['Brittany Montano', 'Pearl Liu', 'Examining Livable Transit Oriented Development'],
['Johanna Hernandez Perez', '', 'Tourism Gentrification: The Case of Santurce, Puerto Rico'],
['Mel Liu', 'Lupe Renteria Salome', 'Land Access and Use for Humans & Non-Humans'],
['Jessica Martin', 'Antara Murshed','California Wildfire Incidents and Housing Demographics'],
]

# %%
# add the students to a dataframe
df = pd.DataFrame(students, columns=['First','Second','Topic'])
  
# print dataframe.
df
# Out:
#                       First                          Second  \
# 0                Erik Felix                       Kevin Liu
# 1           Nicole Matteson  Chaithra Ananthakrishna Navada
# 2                Bailey Lai         Monica Gonzalez Jimenez
# 3           Elena Savignano                   Yasmina Yusuf
# 4              George Karam                     Omer Sohail
# 5               Carolyn Chu                Leslie Velasquez
# 6          Ariana Hernandez                         Sim Bun
# 7           Estefany Garcia                    Mica O'Brien
# 8               Elliot Shaw                   Michael Rosen
# 9                Lupe Velez                  Antonia Izuogu
# 10         Brittany Montano                       Pearl Liu
# 11  Johanna Hernandez Perez
# 12                  Mel Liu            Lupe Renteria Salome
# 13           Jessica Martin                  Antara Murshed
#
#                                                 Topic
# ...

# %%
# this randomizes the data using .sample
# frac stands for fraction of the data to return, 
# so frac=1 means to return every row
df = df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#                       First                          Second  \
# 0               Carolyn Chu                Leslie Velasquez
# 1           Nicole Matteson  Chaithra Ananthakrishna Navada
# 2                   Mel Liu            Lupe Renteria Salome
# 3                Lupe Velez                  Antonia Izuogu
# 4          Ariana Hernandez                         Sim Bun
# 5            Jessica Martin                  Antara Murshed
# 6                Bailey Lai         Monica Gonzalez Jimenez
# 7               Elliot Shaw                   Michael Rosen
# 8              George Karam                     Omer Sohail
# 9          Brittany Montano                       Pearl Liu
# 10          Estefany Garcia                    Mica O'Brien
# 11  Johanna Hernandez Perez
# 12          Elena Savignano                   Yasmina Yusuf
# 13               Erik Felix                       Kevin Liu
#
#                                                 Topic
# ...
